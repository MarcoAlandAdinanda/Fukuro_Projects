# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

null = np.array([0, 0], dtype=float)
test = np.array([5, 0], dtype=float)
mid = np.array([0, 5], dtype=float)
a = np.array([5.45, 1.12])
b = np.array([-3.86, 4.32])

def calculate(vec1, vec2):
    vec = vec2 - vec1
    return np.arctan2(vec[1], vec[0])

z1 = np.arctan2(mid[1], mid[0])
z2 = np.arctan2(test[1], test[0])
z3 = np.arctan2(a[1], a[0])
resultsA = z1 - z2

np.degrees(resultsA)

# result1 = calculate(null, a)
# result2 = calculate(null, b)
# result = result2 - result1
# np.degrees(result)
# Out:
# 90.0
